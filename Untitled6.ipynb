# %% [markdown]
# <a href="https://colab.research.google.com/github/monuminu/affine_hackathon/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files.upload()
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-206446d8-5068-4476-81b2-aa13d31b4635" name="files[]" multiple disabled />
#      <output id="result-206446d8-5068-4476-81b2-aa13d31b4635">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
# !pip install kaggle
# !pip install luminoth
# Out:
# ...
#     100% |████████████████████████████████| 61kB 2.8MB/s
# ...
#     100% |████████████████████████████████| 235kB 5.3MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/8b/21/3b/a0076243c6ae12a6215b2da515fe06b539aee7217b406e510e
# done
#   Stored in directory: /root/.cache/pip/wheels/e3/65/da/2045deea3098ed7471eca0e2460cfbd3fdfe8c1d6fa6fcac92
# Successfully built kaggle python-slugify
# ...
#     100% |████████████████████████████████| 225kB 5.2MB/s
# ...
#     100% |████████████████████████████████| 5.8MB 4.6MB/s
# ...
#     100% |████████████████████████████████| 2.3MB 13.2MB/s
# ...
#     100% |████████████████████████████████| 92kB 25.4MB/s
# ...
#     100% |████████████████████████████████| 624kB 23.8MB/s
# ...
#     100% |████████████████████████████████| 71kB 21.6MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/3f/f0/7c/1ec164f1dc11a6e0ef58463f5e25e83d9c6f661e2e8e70bcef
# Successfully built easydict
# ...

# %%
# !kaggle datasets download -d monuirctc/tsaaaaa
# Out:
# ...
#  98% 595M/605M [00:06<00:00, 49.1MB/s]
# 100% 605M/605M [00:06<00:00, 91.3MB/s]

# %%
# !unzip tsaaaaa.zip
# Out:
# Archive:  tsaaaaa.zip
#    creating: data/
#    creating: data/images/
#   inflating: data/images/0101_003.png
#   inflating: data/images/0110_099.png
#   inflating: data/images/0113_013.png
#   inflating: data/images/0140_007.png
#   inflating: data/images/0146_281.png
#   inflating: data/images/0147_090.png
#   inflating: data/images/0147_125.png
#   inflating: data/images/0147_256.png
#   inflating: data/images/0148_271.png
#   inflating: data/images/0148_479.png
#   inflating: data/images/0151_180.png
#   inflating: data/images/0151_208.png
#   inflating: data/images/0154_080.png
#   inflating: data/images/0154_474.png
#   inflating: data/images/0155_081.png
#   inflating: data/images/0199_384.png
#   inflating: data/images/0203_075.png
#   inflating: data/images/0203_207.png
#   inflating: data/images/0206_007.png
#   inflating: data/images/0206_048.png
#   inflating: data/images/0207_025.png
#   inflating: data/images/0209_207.png
#   inflating: data/images/0210_111.png
# ...

# %%
# !ls data/train

# %%
# !lumi dataset transform --type csv --data-dir data/ --output-dir tfdata/ --split train --split val --only-classes=table
# Out:
# INFO:tensorflow:Saving split "train" in output_dir = tfdata/
#   [####################################]  100%
# INFO:tensorflow:Saved 338 records to "tfdata/train.tfrecords"
# INFO:tensorflow:Composition per class (train):
# INFO:tensorflow:	table: 418
# INFO:tensorflow:Saving split "val" in output_dir = tfdata/
#   [####################################]  100%
# INFO:tensorflow:Saved 65 records to "tfdata/val.tfrecords"
# INFO:tensorflow:Composition per class (val):
# INFO:tensorflow:	table: 100

# %%
# !rm config.yml
from google.colab import files
files.upload()
# Out:
# rm: cannot remove 'config.yml': No such file or directory
#      <input type="file" id="files-8b3757d6-7321-4436-bf79-241dc672396e" name="files[]" multiple disabled />
#      <output id="result-8b3757d6-7321-4436-bf79-241dc672396e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving config.yml to config.yml
# ...

# %%
# !lumi train -c config.yml
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/luminoth/datasets/base_dataset.py:44: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/input.py:276: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# ...

# %%
# !lumi checkpoint create config.yml
# Out:
# Creating checkpoint for given configuration...
# Checkpoint 110c2ee8456b created successfully.

# %%
# !lumi checkpoint list
# Out:
# ...
# |           id |                  name |       alias | source |         status |
# ...
# | 110c2ee8456b |                       |             |  local |          LOCAL |
# ...

# %%
# !lumi checkpoint export 110c2ee8456b 
# !lumi checkpoint download 110c2ee8456b
# Out:
# Checkpoint 110c2ee8456b exported successfully.
# Checkpoint is not remote. If you intended to download a remote checkpoint and used an alias, try using the id directly.

# %%
from google.colab import files
files.download('110c2ee8456b.tar')
